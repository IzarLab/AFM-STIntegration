# %%
library(Seurat)
library(enrichR)
library(ggplot2)
library(dplyr)
library(stringr)
library(httr)
library(jsonlite)
library(hash)
library(readr)
library(purrr)
library(ggrepel)

library(RColorBrewer)  # For color palettes
library(DESeq2)
library("scales")
library(ggpubr)

# %%
myeloid <- readRDS("myeloid.rds")

# %%
convert_human_to_mouse <- function(gene_list, file_path = "HOM_MouseHumanSequence.rpt") {
    output = c()
    
    # Check if the file already exists
    if (!file.exists(file_path)) {
        # Download the mouse-human gene mapping file from the JAX website
        download.file("https://www.informatics.jax.org/downloads/reports/HOM_MouseHumanSequence.rpt", file_path)
    }
    
    # Load the mouse-human gene mapping file
    mouse_human_genes = read.csv(file_path, sep = "\t")
    
    # Loop through each gene in the provided gene list
    for (gene in gene_list) {
        # Get the class key for the human gene
        class_key = (mouse_human_genes %>% filter(Symbol == gene & Common.Organism.Name == "human"))[['DB.Class.Key']]
        
        # If a valid class key is found, get the corresponding mouse genes
        if (!identical(class_key, integer(0))) {
            mouse_genes = (mouse_human_genes %>% filter(DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"))[,"Symbol"]
            
            # Add each mouse gene to the output list
            for (mouse_gene in mouse_genes) {
                output = rbind(c(gene, mouse_gene), output)
            }
        }
    }
    return (output)
}

mye_sigs = read.csv("~/Durva/myeloid/myeloid.signature.csv")
DefaultAssay(myeloid) <- "RNA"
for(i in 1:ncol(mye_sigs)) {      
    tryCatch({
        # Extract and clean the signature list
        sigs = list(mye_sigs[[i]])
        sigs2 = sigs[[1]]
        sigs = sigs2[!is.na(sigs2)]
        
        # Print the column name
        print(colnames(mye_sigs[i])[1])
        
        # Attempt conversion and module score addition
        converted_genes <- convert_human_to_mouse(sigs)
        print(list(converted_genes))
        
        # Add module score with converted genes
        myeloid <- AddModuleScore(myeloid,
                                  features = list(converted_genes[,2]),
                                  name = colnames(mye_sigs[i])[1])
    }, error = function(e) {
        # Ignore any errors by printing a simple message
        message("An error occurred and was ignored.")
    })
}
# Out:
# [1] "cDC1"
# [[1]]
#      [,1]       [,2]
# [1,] "TRBV11-3" "Trbv14"
# [2,] "WFDC21P"  "Wfdc21"
# [3,] "CPVL"     "Cpvl"
# [4,] "ENPP1"    "Enpp1"
# [5,] "CLNK"     "Clnk"
# [6,] "CLEC9A"   "Clec9a"
# Warning message:
# “The following features are not present in the object: Trbv14, not searching for symbol synonyms”
# [1] "DC2"
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# [[1]]
#      [,1]       [,2]
# [1,] "IL22RA2"  "Il22ra2"
# [2,] "CLEC10A"  "Clec10a"
# [3,] "JAML"     "Jaml"
# [4,] "TRBV10-2" "Trbv13-2"
# [5,] "TRBV10-2" "Trbv13-3"
# [6,] "TRBV10-2" "Trbv13-1"
# [7,] "PRDM16"   "Prdm16"
# Warning message:
# “The following features are not present in the object: Il22ra2, Trbv13-2, Trbv13-3, Trbv13-1, not searching for symbol synonyms”
# [1] "Cycling.Myleoid"
# [[1]]
#      [,1]    [,2]
# [1,] "ITGAM" "Itgam"
# [2,] "CENPF" "Cenpf"
# [3,] "CDCA8" "Cdca8"
#
# [1] "DC3"
# [[1]]
#      [,1]     [,2]
# [1,] "FCN1"   "Fcnb"
# [2,] "CMA1"   "Cma1"
# [3,] "FCER1A" "Fcer1a"
# [4,] "SAMSN1" "Samsn1"
# [5,] "LAMP3"  "Lamp3"
# [6,] "CD274"  "Cd274"
# Warning message:
# “The following features are not present in the object: Fcnb, Fcer1a, not searching for symbol synonyms”
# [1] "Developing.granulocytes.neutrophils"
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# [[1]]
#       [,1]      [,2]
#  [1,] "LYZ"     "Lyz3"
#  [2,] "LYZ"     "Lyz2"
#  [3,] "DEFA1"   "Defa26"
#  [4,] "FCGR1A"  "Fcgr1"
#  [5,] "CD24"    "Cd24a"
#  [6,] "JAML"    "Jaml"
#  [7,] "CEACAM8" "Psg20"
#  [8,] "FCGR3A"  "Fcgr4"
#  [9,] "CD63"    "Cd63"
# [10,] "NAMPT"   "Nampt"
# [11,] "CAMK1D"  "Camk1d"
# [12,] "ITGAX"   "Itgax"
# Warning message:
# “The following features are not present in the object: Lyz3, Defa26, not searching for symbol synonyms”
# [1] "Macrophage.1"
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# [[1]]
#       [,1]    [,2]
#  [1,] "CD86"  "Cd86"
#  [2,] "CD80"  "Cd80"
#  [3,] "TLR4"  "Tlr4"
#  [4,] "TLR2"  "Tlr2"
#  [5,] "NOS2"  "Nos2"
#  [6,] "IL6"   "Il6"
#  [7,] "IL1B"  "Il1b"
#  [8,] "IL1A"  "Il1a"
#  [9,] "IFI44" "Ifi44"
# [10,] "MX2"   "Mx1"
# [11,] "MX1"   "Mx1"
# [12,] "GBP5"  "Gbp5"
# [13,] "GBP1"  "Gbp2b"
# [14,] "GBP1"  "Gbp2"
# [15,] "STAT1" "Stat1"
# Warning message:
# “The following features are not present in the object: Mx1, not searching for symbol synonyms”
# [1] "Macrophage.2"
# [[1]]
#       [,1]      [,2]
#  [1,] "CD163"   "Cd163"
#  [2,] "ARG1"    "Arg1"
#  [3,] "PPARG"   "Pparg"
#  [4,] "DENND4C" "Dennd4c"
#  [5,] "FBP1"    "Fbp1"
#  [6,] "LTA4H"   "Lta4h"
#  [7,] "ANO5"    "Ano5"
#  [8,] "PPARG"   "Pparg"
#  [9,] "CYP27A1" "Cyp27a1"
# [10,] "MARCO"   "Marco"
# [11,] "MERTK"   "Mertk"
# [12,] "CD163"   "Cd163"
# Warning message:
# “The following features are not present in the object: Fbp1, Marco, not searching for symbol synonyms”
# [1] "Mast.cells"
# [[1]]
#      [,1]     [,2]
# [1,] "FCER2"  "Fcer2a"
# [2,] "MS4A2"  "Ms4a2"
# [3,] "IL18R1" "Il18r1"
# [4,] "KIT"    "Kit"
# [5,] "GATA2"  "Gata2"
# [6,] "PBX1"   "Pbx1"
#
# [1] "Microglia"
# [[1]]
#      [,1]     [,2]
# [1,] "NCK2"   "Nck2"
# [2,] "SLC2A5" "Slc2a5"
# [3,] "NAV3"   "Nav3"
# [4,] "P2RY12" "P2ry12"
#
# [1] "Monocytes.MDM"
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# [[1]]
#       [,1]       [,2]
#  [1,] "SERPINA1" "Serpina1d"
#  [2,] "SERPINA1" "Serpina1a"
#  [3,] "LYZ"      "Lyz3"
#  [4,] "LYZ"      "Lyz2"
#  [5,] "FCN1"     "Fcnb"
#  [6,] "FCGR3A"   "Fcgr4"
#  [7,] "MS4A6A"   "Ms4a6b"
#  [8,] "HLA-DRA"  "H2-Ea"
#  [9,] "OAS1"     "Oas1a"
# [10,] "GBP1"     "Gbp2b"
# [11,] "GBP1"     "Gbp2"
# [12,] "FCGR1A"   "Fcgr1"
# [13,] "FCGR3B"   "Fcgr4"
# [14,] "CD14"     "Cd14"
# [15,] "LYZ"      "Lyz3"
# [16,] "LYZ"      "Lyz2"
# [17,] "VIM"      "Vim"
# [18,] "FCN1"     "Fcnb"
# [19,] "VCAN"     "Vcan"
# Warning message:
# “The following features are not present in the object: Serpina1d, Serpina1a, Lyz3, Fcnb, H2-Ea, not searching for symbol synonyms”
# [1] "Langerhans.like.cells"
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# [[1]]
#       [,1]       [,2]
#  [1,] "HIP1"     "Hip1"
#  [2,] "CLDN1"    "Cldn1"
#  [3,] "CD207"    "Cd207"
#  [4,] "FCGR2A"   "Fcgr3"
#  [5,] "HLA-DRB5" "H2-Eb2"
#  [6,] "HLA-DRB1" "H2-Eb2"
#  [7,] "HLA-DRA"  "H2-Ea"
#  [8,] "HLA-DQB2" "H2-Ab1"
#  [9,] "HLA-DQB1" "H2-Ab1"
# [10,] "HLA-DQA2" "H2-Aa"
# [11,] "HLA-DQA1" "H2-Aa"
# [12,] "HLA-DMB"  "H2-DMb1"
# [13,] "HLA-DMA"  "H2-DMa"
# [14,] "FCGR1A"   "Fcgr1"
# Warning message:
# “The following features are not present in the object: Cd207, H2-Ea, not searching for symbol synonyms”
# [1] "Myeloid.derived.suppressor.cells"
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# [[1]]
#      [,1]      [,2]
# [1,] "FCGR3A"  "Fcgr4"
# [2,] "CD1D"    "Cd1d2"
# [3,] "CD1D"    "Cd1d1"
# [4,] "IL4R"    "Il4ra"
# [5,] "CEACAM8" "Psg20"
# Warning message:
# “The following features are not present in the object: Cd1d2, not searching for symbol synonyms”
# [1] "Dendritic.cells"
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# [[1]]
#       [,1]       [,2]
#  [1,] "HLA-DRB5" "H2-Eb2"
#  [2,] "HLA-C"    "H2-Q2"
#  [3,] "HLA-C"    "H2-M1"
#  [4,] "HLA-C"    "H2-M10.5"
#  [5,] "HLA-B"    "H2-Q2"
#  [6,] "HLA-B"    "H2-M1"
#  [7,] "HLA-B"    "H2-M10.5"
#  [8,] "LYZ"      "Lyz3"
#  [9,] "LYZ"      "Lyz2"
# [10,] "SIGLEC6"  "Cd33"
# [11,] "SERPINA1" "Serpina1d"
# [12,] "SERPINA1" "Serpina1a"
# [13,] "FTL"      "Ftl1-ps2"
# [14,] "FCGR3A"   "Fcgr4"
# [15,] "LILRB2"   "Pirb"
# [16,] "HLA-DRB1" "H2-Eb2"
# [17,] "HLA-DQB1" "H2-Ab1"
# [18,] "HLA-DMA"  "H2-DMa"
# [19,] "HLA-DMB"  "H2-DMb1"
# [20,] "HLA-DQA1" "H2-Aa"
# [21,] "HLA-DRA"  "H2-Ea"
# [22,] "CD209"    "Cd209e"
# [23,] "CD209"    "Cd209a"
# Warning message:
# “The following features are not present in the object: H2-M1, H2-M10.5, Lyz3, Serpina1d, Serpina1a, Ftl1-ps2, H2-Ea, Cd209e, not searching for symbol synonyms”
# [1] "Migratory.DC"
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# [[1]]
#      [,1]       [,2]
# [1,] "FCGR2C"   "Fcgr2b"
# [2,] "TRBV10-2" "Trbv13-2"
# [3,] "TRBV10-2" "Trbv13-3"
# [4,] "TRBV10-2" "Trbv13-1"
# [5,] "ENTHD1"   "Enthd1"
# Warning message:
# “The following features are not present in the object: Trbv13-2, Trbv13-3, Trbv13-1, not searching for symbol synonyms”
# [1] "Transitional.DC"
# [[1]]
#      [,1]    [,2]
# [1,] "FOXH1" "Foxh1"
# [2,] "SYCP1" "Sycp1"
# [3,] "SCT"   "Sct"
# Warning message:
# “The following features are not present in the object: Foxh1, Sct, not searching for symbol synonyms”
# [1] "DC.precursor"
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# [[1]]
#      [,1]       [,2]
# [1,] "ANKRD34B" "Ankrd34b"
# [2,] "RNASE2"   "Ear4"
# [3,] "PCLAF"    "Pclaf"
# Warning message:
# “The following features are not present in the object: Ankrd34b, Ear4, not searching for symbol synonyms”
# [1] "Granulocytes"
# [[1]]
#      [,1]       [,2]
# [1,] "ADCYAP1"  "Adcyap1"
# [2,] "TRBV11-3" "Trbv14"
# Warning message:
# “The following features are not present in the object: Adcyap1, Trbv14, not searching for symbol synonyms”
# Warning message in AddModuleScore(myeloid, features = list(converted_genes[, 2]), :
# “Could not find enough features in the object from the following feature lists:  Attempting to match case...”
# An error occurred and was ignored.
# [1] "Neutrophils"
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# [[1]]
#      [,1]   [,2]
# [1,] "XCR1" "Xcr1"
# [2,] "SYN3" "Syn3"
# Warning message:
# “The following features are not present in the object: Xcr1, not searching for symbol synonyms”
# [1] "Neutrophil.myeloid.progenitor"
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# [[1]]
#      [,1]       [,2]
# [1,] "KCNE5"    "Kcne5"
# [2,] "FMO2"     "Fmo2"
# [3,] "TRBV10-1" "Trbv13-2"
# [4,] "TRBV10-1" "Trbv13-3"
# [5,] "TRBV10-1" "Trbv13-1"
# [6,] "MPO"      "Mpo"
# [7,] "MS4A3"    "Ms4a3"
# Warning message:
# “The following features are not present in the object: Kcne5, Trbv13-2, Trbv13-3, Trbv13-1, Mpo, Ms4a3, not searching for symbol synonyms”
# [1] "Intermediate.macrophages"
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# Warning message:
# “There was 1 warning in `filter()`.
# ℹ In argument: `DB.Class.Key == class_key & Common.Organism.Name == "mouse, laboratory"`.
# Caused by warning in `DB.Class.Key == class_key`:
# ! longer object length is not a multiple of shorter object length”
# [[1]]
#      [,1]     [,2]
# [1,] "IL22"   "Il22"
# [2,] "TCL1B"  "Tcl1b3"
# [3,] "OR2A25" "Or2a25"
# [4,] "IGHE"   "Ighe"
# Warning message:
# “The following features are not present in the object: Il22, Tcl1b3, Or2a25, Ighe, not searching for symbol synonyms”
# Warning message in AddModuleScore(myeloid, features = list(converted_genes[, 2]), :
# “Could not find enough features in the object from the following feature lists:  Attempting to match case...”
# An error occurred and was ignored.

# %%
myeloid@meta.data
# Out:
#                          orig.ident nCount_RNA nFeature_RNA percent.mt
# LAC12_ACCGTAAAGTACGTAA-1 LAC12      6494       2517         0
# LAC12_TTCTCCTCAGGGCATA-1 LAC12      5595       2568         0
# LAC12_GCACTCTGTTCCACGG-1 LAC12      4233       2061         0
# LAC12_GATGCTAGTGGTGTAG-1 LAC12      3620       1842         0
# LAC12_TCGTACCGTCTAGTGT-1 LAC12      3295       1907         0
# LAC12_AGCTCTCTCAGCTCTC-1 LAC12      3047       1714         0
# LAC12_CCGTTCAGTCTCATCC-1 LAC12      3092       1677         0
# LAC12_CGGACTGGTTCTGAAC-1 LAC12      3027       1702         0
# LAC12_TCTGGAACAAGGGTCA-1 LAC12      3029       1550         0
# LAC12_CGGAGTCTCACTCTTA-1 LAC12      3022       1657         0
# LAC12_CATTATCGTATCAGTC-1 LAC12      2910       1610         0
# LAC12_TGCACCTGTTCCACGG-1 LAC12      2826       1630         0
# LAC12_TCACGAACATGGTAGG-1 LAC12      2830       1560         0
# LAC12_CACCACTAGGATGCGT-1 LAC12      2766       1537         0
# LAC12_TCATTTGCAAAGCGGT-1 LAC12      2699       1544         0
# LAC12_CAGGTGCCAGTTAACC-1 LAC12      2603       1533         0
# LAC6_GCATACACATGTAAGA-1  -0.05711500  -0.10770518
# LAC6_CTACGTCTCATCACCC-1   0.00000000  -0.03150441
# LAC6_AAGGCAGTCCCTCAGT-1  -0.02483990   0.00000000
# LAC6_CTAGTGAAGTCATCCA-1   0.00000000   0.00000000
# LAC6_CGCCAAGCACGTAAGG-1   0.00000000  -0.05805042
# LAC6_CCTTACGAGTGTACCT-1   0.00000000  -0.02530572
# LAC6_AATCCAGTCAACACGT-1   0.00000000   0.00000000
# LAC6_GATGAGGCACACATGT-1  -0.10314883  -0.02578721
# LAC6_GCACATATCGCATGAT-1   0.00000000   0.00000000

# %%
# Set Default Assay
DefaultAssay(myeloid) <- "RNA"

# Extract avAFM data and convert it into a vector
lcv_data <- as.vector(unlist(myeloid@meta.data$AvAFM))

# Calculate quartiles and create a factor variable 'm_cell_quartile' for each sample separately
quartile_breaks <- myeloid@meta.data %>%
    group_by(orig.ident) %>%
    mutate(m_cell_quartile = cut(AvAFM,
                                 breaks = quantile(AvAFM, probs = c(0, 0.25, 0.50, 0.75, 1), na.rm = TRUE),
                                 include.lowest = TRUE,
                                 labels = c("Q1 (Low AFM)", "Q2", "Q3", "Q4 (High AFM)")))

# Add the quartile-based grouping back to metadata
myeloid@meta.data$m_cell_quartile <- unlist(quartile_breaks$m_cell_quartile)

# Prepare DESeqDataSet with the design including both orig.ident and m_cell_quartile
dds_unfilt <- DESeqDataSetFromMatrix(countData = myeloid@assays$RNA@counts,
                              colData = myeloid@meta.data,
                              design = ~ orig.ident + m_cell_quartile)

# Filter out low counts
#keep <- rowSums(counts(dds) >= 5) >= 5, -0.19147503, 0.07304503
param_1 = 5
param_2 = 5


keep <- rowSums(counts(dds_unfilt) >= param_1) >= param_2
dds <- dds_unfilt[keep,]

# Estimate size factors and run DESeq
dds <- estimateSizeFactors(dds, type='poscounts')
dds <- DESeq(dds)

# Get results for a specific quartile comparison, for example, Q4 (High AFM) vs Q1 (Low AFM)
results_data <- as.data.frame(results(dds, contrast = c("m_cell_quartile", "Q4 (High AFM)", "Q1 (Low AFM)")))

# Prepare data for plotting
results_data$gene <- rownames(results_data)
results_data$logp <- -log10(results_data$pvalue)

# Generate volcano plot

options(repr.plot.width = 8, repr.plot.height = 6)  # Adjust width and height as needed

# Generate volcano plot
volcano_plot <- ggplot(results_data, aes(x = log2FoldChange, y = logp)) +
    geom_point(aes(color = pvalue < 0.05)) +
    scale_color_manual(values = c("grey", "red")) +
    geom_text(data = subset(results_data, pvalue < 0.10), aes(label = gene), vjust = 1.5, hjust = 0.5, size = 4, check_overlap = TRUE) + # increased text size
    geom_vline(xintercept = 0, linetype = "dashed", color = "black") + # vertical line at x = 0
    theme_minimal() +
    theme(
        axis.title = element_text(size = 16, color = "black"),  # increased font size for axis titles
        axis.text = element_text(size = 16, color = "black"),    # increased font size for axis labels
        axis.line = element_line(color = "black")                # black axis lines
    ) +
    labs(
        x = "Log2 Fold Change",
        y = "-log10(p-value)"
    )

# Print the plot
print(volcano_plot)

GOI <- subset(results_data, log2FoldChange > 0)
GOI <- subset(GOI, pvalue < 0.05)
genes_f <- GOI$gene

myeloid<- AddModuleScore(myeloid,
                          features = list(GOI$gene),
                          name="myeloid_signature_quart_samp")

GOI <- subset(results_data, log2FoldChange < 0)
GOI <- subset(GOI, pvalue < 0.05)
genes_r <- GOI$gene
# Out:
# converting counts to integer mode
#
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”
#   Note: levels of factors in the design contain characters other than
#   letters, numbers, '_' and '.'. It is recommended (but not required) to use
#   only letters, numbers, and delimiters '_' or '.', as these are safe characters
#   for column names in R. [This is a message, not a warning or an error]
#
#   Note: levels of factors in the design contain characters other than
#   letters, numbers, '_' and '.'. It is recommended (but not required) to use
#   only letters, numbers, and delimiters '_' or '.', as these are safe characters
#   for column names in R. [This is a message, not a warning or an error]
#
# using pre-existing size factors
#
# estimating dispersions
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# -- note: fitType='parametric', but the dispersion trend was not well captured by the
#    function: y = a/x + b, and a local regression fit was automatically substituted.
#    specify fitType='local' or 'mean' to avoid this message next time.
#
#   Note: levels of factors in the design contain characters other than
#   letters, numbers, '_' and '.'. It is recommended (but not required) to use
#   only letters, numbers, and delimiters '_' or '.', as these are safe characters
#   for column names in R. [This is a message, not a warning or an error]
#
# final dispersion estimates
#
#   Note: levels of factors in the design contain characters other than
#   letters, numbers, '_' and '.'. It is recommended (but not required) to use
#   only letters, numbers, and delimiters '_' or '.', as these are safe characters
#   for column names in R. [This is a message, not a warning or an error]
#
# fitting model and testing
#
#   Note: levels of factors in the design contain characters other than
#   letters, numbers, '_' and '.'. It is recommended (but not required) to use
#   only letters, numbers, and delimiters '_' or '.', as these are safe characters
#   for column names in R. [This is a message, not a warning or an error]
#
# -- replacing outliers and refitting for 1 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
#
# estimating dispersions
#
#   Note: levels of factors in the design contain characters other than
#   letters, numbers, '_' and '.'. It is recommended (but not required) to use
#   only letters, numbers, and delimiters '_' or '.', as these are safe characters
#   for column names in R. [This is a message, not a warning or an error]
#
# fitting model and testing
#
#   Note: levels of factors in the design contain characters other than
#   letters, numbers, '_' and '.'. It is recommended (but not required) to use
#   only letters, numbers, and delimiters '_' or '.', as these are safe characters
#   for column names in R. [This is a message, not a warning or an error]
# plot without title

# %%
# Generate volcano plot with additional labels for Ct74 and Ciita
volcano_plot <- ggplot(results_data, aes(x = log2FoldChange, y = logp)) +
    geom_point(aes(color = pvalue < 0.05)) +
    scale_color_manual(values = c("grey", "red")) +
    # Label genes with p-value < 0.10 and also Ct74 and Ciita
    
    geom_text_repel(data = subset(results_data, pvalue < 0.10), 
                    aes(label = gene), size = 4, box.padding = 0.4, max.overlaps = Inf) +
    geom_vline(xintercept = 0, linetype = "dashed", color = "black") + # vertical line at x = 0
    theme_minimal() +
    theme(
        axis.title = element_text(size = 16, color = "black"),  # increased font size for axis titles
        axis.text = element_text(size = 16, color = "black"),   # increased font size for axis labels
        axis.line = element_line(color = "black")               # black axis lines
    ) +
    labs(
        x = "Log2 Fold Change",
        y = "-log10(p-value)"
    )

# Print the plot
print(volcano_plot)
# Out:
# plot without title

# %%
convert_mouse_to_human <- function(gene_list, file_path = "HOM_MouseHumanSequence.rpt") {
    output = c()
    
    # Check if the file already exists
    if (!file.exists(file_path)) {
        # Download the mouse-human gene mapping file from the JAX website
        download.file("https://www.informatics.jax.org/downloads/reports/HOM_MouseHumanSequence.rpt", file_path)
    }
    
    # Load the mouse-human gene mapping file
    mouse_human_genes = read.csv(file_path, sep = "\t")
    
    # Loop through each gene in the provided mouse gene list
    for (gene in gene_list) {
        # Get the class key for the mouse gene
        class_key = (mouse_human_genes %>% filter(Symbol == gene & Common.Organism.Name == "mouse, laboratory"))[['DB.Class.Key']]
        
        # If a valid class key is found, get the corresponding human genes
        if (!identical(class_key, integer(0))) {
            human_genes = (mouse_human_genes %>% filter(DB.Class.Key == class_key & Common.Organism.Name == "human"))[,"Symbol"]
            
            # Add each human gene to the output list
            for (human_gene in human_genes) {
                output = rbind(c(gene, human_gene), output)
            }
        }
    }
    return (output)
}

convert_mouse_to_human(genes_f)[,2]
# Out:
# [1] "RTN3"   "MALAT1" "PAN3"   "CD44"   "BAZ2B"

# %%
GOI <- subset(results_data, log2FoldChange > 0)
GOI <- subset(GOI, pvalue < 0.25)
genes_f <- GOI$gene

myeloid<- AddModuleScore(myeloid,
                          features = list(GOI$gene),
                          name="myeloid_signature_quart_samp")

GOI <- subset(results_data, log2FoldChange < 0)
GOI <- subset(GOI, pvalue < 0.25)
genes_r <- GOI$gene


genes <- convert_mouse_to_human(genes_f)[,2]

# Load Enrichr
setEnrichrSite("Enrichr") # Human genes
websiteLive <- TRUE
dbs <- listEnrichrDbs()
if (is.null(dbs)) websiteLive <- FALSE
if (websiteLive) head(dbs)
dbs <- c("MSigDB_Hallmark_2020","GO_Biological_Process_2023")
if (websiteLive) {
  enriched <- enrichr(genes, dbs)
}
mut_enr_ch<-mutate(enriched[[1]], qscore = -log(Adjusted.P.value, base=10))
mut_enr_go<-mutate(enriched[[2]], qscore = -log(Adjusted.P.value, base=10))
mut_enr <- mut_enr_go
print(mut_enr$Term)
mut_enr <- subset(mut_enr,Adjusted.P.value	 < 0.05 & qscore > 1)

#mut_enr<- mut_enr[order(mut_enr$Adjusted.P.value),]
mp = ""
cohort = "Cells Affillated with Highest Quartile AFM Measurements"
enrichdbs = "Cancer_Hallmarks_and_Gene_Ontology"
topn = ""


h_mut_enr1 <- mut_enr[1:25,]
h_mut_enr <- h_mut_enr1


Sys.sleep(3)

genes <- convert_mouse_to_human(genes_r)[,2]


# Load Enrichr
setEnrichrSite("Enrichr") # Human genes
websiteLive <- TRUE
dbs <- listEnrichrDbs()
if (is.null(dbs)) websiteLive <- FALSE
if (websiteLive) head(dbs)
dbs <- c("MSigDB_Hallmark_2020","GO_Biological_Process_2023")
if (websiteLive) {
  enriched <- enrichr(genes, dbs)
}
mut_enr_ch<-mutate(enriched[[1]], qscore = -log(Adjusted.P.value, base=10))
mut_enr_go<-mutate(enriched[[2]], qscore = -log(Adjusted.P.value, base=10))
mut_enr <- mut_enr_go
mut_enr <- subset(mut_enr,Adjusted.P.value	 < 0.05 & qscore > 1)
print(mut_enr_go$Term)

#mut_enr<- mut_enr[order(mut_enr$Adjusted.P.value),]
mp = ""
cohort = "Cells Affillated with Highest Quartile AFM Measurements"
enrichdbs = "Cancer_Hallmarks_and_Gene_Ontology"
topn = ""


h_mut_enr1 <- mut_enr[1:25,]
# Out:
# Connection changed to https://maayanlab.cloud/Enrichr/
#
# Connection is Live!
#   geneCoverage genesPerTerm libraryName
# 1 13362         275         Genome_Browser_PWMs
# 2 27884        1284         TRANSFAC_and_JASPAR_PWMs
# 3  6002          77         Transcription_Factor_PPIs
# 4 47172        1370         ChEA_2013
# 5 47107         509         Drug_Perturbations_from_GEO_2014
# 6 21493        3713         ENCODE_TF_ChIP-seq_2014
#   link                                                     numTerms
# 1 http://hgdownload.cse.ucsc.edu/goldenPath/hg18/database/ 615
# 2 http://jaspar.genereg.net/html/DOWNLOAD/                 326
# 3                                                          290
# 4 http://amp.pharm.mssm.edu/lib/cheadownload.jsp           353
# 5 http://www.ncbi.nlm.nih.gov/geo/                         701
# 6 http://genome.ucsc.edu/ENCODE/downloads.html             498
#   appyter                                  categoryId
# 1 ea115789fcbf12797fd692cec6df0ab4dbc79c6a 1
# 2 7d42eb43a64a4e3b20d721fc7148f685b53b6b30 1
# 3 849f222220618e2599d925b6b51868cf1dab3763 1
# 4 7ebe772afb55b63b41b79dd8d06ea0fdd9fa2630 7
# 5 ad270a6876534b7cb063e004289dcd4d3164f342 7
# 6 497787ebc418d308045efb63b8586f10c526af51 7
# Uploading data to Enrichr... Done.
#   Querying MSigDB_Hallmark_2020... Done.
#   Querying GO_Biological_Process_2023... Done.
# Parsing results... Done.
#   [1] "Positive Regulation Of Leukocyte Cell-Cell Adhesion (GO:1903039)"
#   [2] "MHC Class II Protein Complex Assembly (GO:0002399)"
#   [3] "Peptide Antigen Assembly With MHC Class II Protein Complex (GO:0002503)"
#   [4] "Peptide Antigen Assembly With MHC Protein Complex (GO:0002501)"
#   [5] "Immunoglobulin Production Involved In Immunoglobulin-Mediated Immune Response (GO:0002381)"
#   [6] "Antigen Processing And Presentation Of Exogenous Peptide Antigen Via MHC Class II (GO:0019886)"
#   [7] "Antigen Processing And Presentation Of Peptide Antigen Via MHC Class II (GO:0002495)"
#   [8] "Immunoglobulin Mediated Immune Response (GO:0016064)"
#   [9] "Antigen Processing And Presentation Of Exogenous Peptide Antigen (GO:0002478)"
#  [10] "Positive Regulation Of Lymphocyte Activation (GO:0051251)"
#  [11] "Regulation Of T Cell Activation (GO:0050863)"
#  [12] "Regulation Of Amyloid-Beta Formation (GO:1902003)"
#  [13] "Positive Regulation Of T Cell Mediated Immune Response To Tumor Cell (GO:0002842)"
#  [14] "Positive Regulation Of T Cell Activation (GO:0050870)"
#  [15] "Positive Regulation Of Immune Response To Tumor Cell (GO:0002839)"
#  [16] "Regulation Of T Cell Mediated Immune Response To Tumor Cell (GO:0002840)"
#  [17] "Regulation Of CD4-positive, Alpha-Beta T Cell Activation (GO:2000514)"
#  [18] "Antigen Receptor-Mediated Signaling Pathway (GO:0050851)"
#  [19] "Negative Regulation Of Platelet-Derived Growth Factor Receptor Signaling Pathway (GO:0010642)"
#  [20] "Positive Regulation Of CD4-positive, Alpha-Beta T Cell Activation (GO:2000516)"
#  [21] "Defense Response To Protozoan (GO:0042832)"
#  [22] "Negative Regulation Of Amyloid-Beta Formation (GO:1902430)"
#  [23] "Endoplasmic Reticulum Tubular Network Organization (GO:0071786)"
#  [24] "Calcium-Mediated Signaling (GO:0019722)"
#  [25] "Negative Regulation Of ERBB Signaling Pathway (GO:1901185)"
#  [26] "Negative Regulation Of Amyloid Precursor Protein Catabolic Process (GO:1902992)"
#  [27] "Positive Regulation Of Alpha-Beta T Cell Activation (GO:0046635)"
#  [28] "T Cell Receptor Signaling Pathway (GO:0050852)"
#  [29] "Peptidyl-Tyrosine Dephosphorylation (GO:0035335)"
#  [30] "Negative Regulation Of Cell Motility (GO:2000146)"
#  [31] "Positive Regulation Of Immune Effector Process (GO:0002699)"
#  [32] "Positive Regulation Of Intracellular Signal Transduction (GO:1902533)"
#  [33] "Positive Regulation Of T Cell Mediated Immunity (GO:0002711)"
#  [34] "Negative Regulation Of Cell Migration (GO:0030336)"
#  [35] "Regulation Of Epidermal Growth Factor Receptor Signaling Pathway (GO:0042058)"
#  [36] "Brain Development (GO:0007420)"
#  [37] "Amide Biosynthetic Process (GO:0043604)"
#  [38] "Endoplasmic Reticulum Organization (GO:0007029)"
#  [39] "Defense Response To Bacterium (GO:0042742)"
#  [40] "Protein Modification Process (GO:0036211)"
#  [41] "Second-Messenger-Mediated Signaling (GO:0019932)"
#  [42] "Protein Tetramerization (GO:0051262)"
#  [43] "Inflammatory Response (GO:0006954)"
#  [44] "R-loop Processing (GO:0062176)"
#  [45] "Regulation Of Morphogenesis Of A Branching Structure (GO:0060688)"
#  [46] "Positive Regulation Of CD4-positive, CD25-positive, Alpha-Beta Regulatory T Cell Differentiation (GO:0032831)"
#  [47] "Contact Inhibition (GO:0060242)"
#  [48] "Ear Development (GO:0043583)"
#  [49] "Establishment Of Mitotic Sister Chromatid Cohesion (GO:0034087)"
#  [50] "Cellular Hyperosmotic Response (GO:0071474)"
#  [51] "Positive Regulation Of B Cell Receptor Signaling Pathway (GO:0050861)"
#  [52] "Mitotic Nuclear Membrane Disassembly (GO:0007077)"
#  [53] "Release Of Sequestered Calcium Ion Into Cytosol By Sarcoplasmic Reticulum (GO:0014808)"
#  [54] "Regulation Of T-helper Cell Differentiation (GO:0045622)"
#  [55] "Regulation Of Peptidyl-Tyrosine Phosphorylation (GO:0050730)"
#  [56] "Negative Regulation Of Signal Transduction (GO:0009968)"
#  [57] "B Cell Activation (GO:0042113)"
#  [58] "Positive Regulation Of Protein Kinase B Signaling (GO:0051897)"
#  [59] "Negative Regulation Of Amide Metabolic Process (GO:0034249)"
# [677] "Macromolecule Biosynthetic Process (GO:0009059)"
# [678] "Phosphate-Containing Compound Metabolic Process (GO:0006796)"
# [679] "Protein Localization To Membrane (GO:0072657)"
# [680] "Modification-Dependent Protein Catabolic Process (GO:0019941)"
# [681] "Positive Regulation Of Protein Metabolic Process (GO:0051247)"
# [682] "Endomembrane System Organization (GO:0010256)"
# [683] "DNA-templated Transcription (GO:0006351)"
# [684] "Regulation Of DNA-templated Transcription (GO:0006355)"
# [685] "Regulation Of Translation (GO:0006417)"
# [686] "Regulation Of Canonical Wnt Signaling Pathway (GO:0060828)"
# [687] "Regulation Of GTPase Activity (GO:0043087)"
# [688] "Protein Polyubiquitination (GO:0000209)"
# [689] "Regulation Of Cell Growth (GO:0001558)"
# [690] "Apoptotic Process (GO:0006915)"
# [691] "Cellular Response To Lipid (GO:0071396)"
# [692] "Chromatin Remodeling (GO:0006338)"
# [693] "Negative Regulation Of Multicellular Organismal Process (GO:0051241)"
# [694] "Positive Regulation Of Developmental Process (GO:0051094)"
# [695] "Translation (GO:0006412)"
# [696] "Inflammatory Response (GO:0006954)"
# [697] "Positive Regulation Of Cellular Process (GO:0048522)"
# [698] "Regulation Of Autophagy (GO:0010506)"
# [699] "Positive Regulation Of DNA-binding Transcription Factor Activity (GO:0051091)"
# [700] "Cytokine-Mediated Signaling Pathway (GO:0019221)"
# [701] "Negative Regulation Of Signal Transduction (GO:0009968)"
# [702] "Plasma Membrane Bounded Cell Projection Assembly (GO:0120031)"
# [703] "Central Nervous System Development (GO:0007417)"
# [704] "Positive Regulation Of Cell Differentiation (GO:0045597)"
# [705] "Gene Expression (GO:0010467)"
# [706] "Regulation Of Intracellular Signal Transduction (GO:1902531)"
# [707] "Positive Regulation Of MAPK Cascade (GO:0043410)"
# [708] "Protein Transport (GO:0015031)"
# [709] "Supramolecular Fiber Organization (GO:0097435)"
# [710] "Proteasome-Mediated Ubiquitin-Dependent Protein Catabolic Process (GO:0043161)"
# [711] "Intracellular Protein Transport (GO:0006886)"
# [712] "Protein Localization (GO:0008104)"
# [713] "Ubiquitin-Dependent Protein Catabolic Process (GO:0006511)"
# [714] "Negative Regulation Of Cell Population Proliferation (GO:0008285)"
# [715] "Negative Regulation Of Programmed Cell Death (GO:0043069)"
# [716] "Organelle Organization (GO:0006996)"
# [717] "Protein Ubiquitination (GO:0016567)"
# [718] "Regulation Of Nucleic Acid-Templated Transcription (GO:1903506)"
# [719] "Negative Regulation Of Apoptotic Process (GO:0043066)"

# %%
GOI <- subset(results_data, log2FoldChange > 0)
GOI <- subset(GOI, pvalue < 0.10)
genes_f <- GOI$gene

myeloid<- AddModuleScore(myeloid,
                          features = list(GOI$gene),
                          name="myeloid_signature_quart_samp")

GOI <- subset(results_data, log2FoldChange < 0)
GOI <- subset(GOI, pvalue < 0.10)
genes_r <- GOI$gene


genes <- convert_mouse_to_human(genes_f)[,2]

# Load Enrichr
setEnrichrSite("Enrichr") # Human genes
websiteLive <- TRUE
dbs <- listEnrichrDbs()
if (is.null(dbs)) websiteLive <- FALSE
if (websiteLive) head(dbs)
dbs <- c("MSigDB_Hallmark_2020","GO_Biological_Process_2023")
if (websiteLive) {
  enriched <- enrichr(genes, dbs)
}
mut_enr_ch<-mutate(enriched[[1]], qscore = -log(Adjusted.P.value, base=10))
mut_enr_go<-mutate(enriched[[2]], qscore = -log(Adjusted.P.value, base=10))
mut_enr <- mut_enr_go
print(mut_enr$Term)

mut_enr_total <- mut_enr
mut_enr_filt <- subset(mut_enr,Adjusted.P.value	 < 0.05 & qscore > 1)

#mut_enr<- mut_enr[order(mut_enr$Adjusted.P.value),]
mp = ""
cohort = "Cells Affillated with Highest Quartile AFM Measurements"
enrichdbs = "Cancer_Hallmarks_and_Gene_Ontology"
topn = ""


h_mut_enr1 <- mut_enr[1:25,]
h_mut_enr <- h_mut_enr1


Sys.sleep(3)

genes <- convert_mouse_to_human(genes_r)[,2]


# Load Enrichr
setEnrichrSite("Enrichr") # Human genes
websiteLive <- TRUE
dbs <- listEnrichrDbs()
if (is.null(dbs)) websiteLive <- FALSE
if (websiteLive) head(dbs)
dbs <- c("MSigDB_Hallmark_2020","GO_Biological_Process_2023")
if (websiteLive) {
  enriched <- enrichr(genes, dbs)
}
mut_enr_ch<-mutate(enriched[[1]], qscore = -log(Adjusted.P.value, base=10))
mut_enr_go<-mutate(enriched[[2]], qscore = -log(Adjusted.P.value, base=10))
mut_enr <- mut_enr_go

mut_enr_total_neg <- mut_enr
mut_enr_filt <- subset(mut_enr,Adjusted.P.value	 < 0.05 & qscore > 1)
print(mut_enr_total_neg$Term)

#mut_enr<- mut_enr[order(mut_enr$Adjusted.P.value),]
mp = ""
cohort = "Cells Affillated with Highest Quartile AFM Measurements"
enrichdbs = "Cancer_Hallmarks_and_Gene_Ontology"
topn = ""


h_mut_enr1 <- mut_enr[1:25,]
# Out:
# Connection changed to https://maayanlab.cloud/Enrichr/
#
# Connection is Live!
#   geneCoverage genesPerTerm libraryName
# 1 13362         275         Genome_Browser_PWMs
# 2 27884        1284         TRANSFAC_and_JASPAR_PWMs
# 3  6002          77         Transcription_Factor_PPIs
# 4 47172        1370         ChEA_2013
# 5 47107         509         Drug_Perturbations_from_GEO_2014
# 6 21493        3713         ENCODE_TF_ChIP-seq_2014
#   link                                                     numTerms
# 1 http://hgdownload.cse.ucsc.edu/goldenPath/hg18/database/ 615
# 2 http://jaspar.genereg.net/html/DOWNLOAD/                 326
# 3                                                          290
# 4 http://amp.pharm.mssm.edu/lib/cheadownload.jsp           353
# 5 http://www.ncbi.nlm.nih.gov/geo/                         701
# 6 http://genome.ucsc.edu/ENCODE/downloads.html             498
#   appyter                                  categoryId
# 1 ea115789fcbf12797fd692cec6df0ab4dbc79c6a 1
# 2 7d42eb43a64a4e3b20d721fc7148f685b53b6b30 1
# 3 849f222220618e2599d925b6b51868cf1dab3763 1
# 4 7ebe772afb55b63b41b79dd8d06ea0fdd9fa2630 7
# 5 ad270a6876534b7cb063e004289dcd4d3164f342 7
# 6 497787ebc418d308045efb63b8586f10c526af51 7
# Uploading data to Enrichr... Done.
#   Querying MSigDB_Hallmark_2020... Done.
#   Querying GO_Biological_Process_2023... Done.
# Parsing results... Done.
#   [1] "Calcium-Mediated Signaling (GO:0019722)"
#   [2] "Regulation Of Peptidyl-Tyrosine Phosphorylation (GO:0050730)"
#   [3] "B Cell Activation (GO:0042113)"
#   [4] "Positive Regulation Of Peptidyl-Tyrosine Phosphorylation (GO:0050731)"
#   [5] "Negative Regulation Of Cell Motility (GO:2000146)"
#   [6] "Antigen Receptor-Mediated Signaling Pathway (GO:0050851)"
#   [7] "Contact Inhibition (GO:0060242)"
#   [8] "Positive Regulation Of B Cell Receptor Signaling Pathway (GO:0050861)"
#   [9] "Mitotic Nuclear Membrane Disassembly (GO:0007077)"
#  [10] "Negative Regulation Of Cell Migration (GO:0030336)"
#  [11] "Leukocyte Aggregation (GO:0070486)"
#  [12] "Nuclear Membrane Disassembly (GO:0051081)"
#  [13] "Positive Regulation Of Vascular Endothelial Growth Factor Receptor Signaling Pathway (GO:0030949)"
#  [14] "Regulation Of Lamellipodium Morphogenesis (GO:2000392)"
#  [15] "Negative Regulation Of Transmembrane Transport (GO:0034763)"
#  [16] "Negative Regulation Of Glucose Transmembrane Transport (GO:0010829)"
#  [17] "Regulation Of Response To Oxidative Stress (GO:1902882)"
#  [18] "Negative Regulation Of Vascular Permeability (GO:0043116)"
#  [19] "Glutamine Family Amino Acid Biosynthetic Process (GO:0009084)"
#  [20] "Negative Regulation Of Platelet-Derived Growth Factor Receptor Signaling Pathway (GO:0010642)"
#  [21] "Lipoprotein Transport (GO:0042953)"
#  [22] "Negative Regulation Of Intrinsic Apoptotic Signaling Pathway In Response To DNA Damage By P53 Class Mediator (GO:1902166)"
#  [23] "Lipoprotein Localization (GO:0044872)"
#  [24] "Regulation Of Platelet-Derived Growth Factor Receptor Signaling Pathway (GO:0010640)"
#  [25] "Regulation Of Intrinsic Apoptotic Signaling Pathway In Response To DNA Damage By P53 Class Mediator (GO:1902165)"
#  [26] "Regulation Of Lamellipodium Organization (GO:1902743)"
#  [27] "Negative Regulation Of DNA Damage Response, Signal Transduction By P53 Class Mediator (GO:0043518)"
#  [28] "Glutamine Metabolic Process (GO:0006541)"
#  [29] "Positive Regulation Of Heterotypic Cell-Cell Adhesion (GO:0034116)"
#  [30] "Hyaluronan Metabolic Process (GO:0030212)"
#  [31] "Epiboly Involved In Wound Healing (GO:0090505)"
#  [32] "Glutamine Family Amino Acid Catabolic Process (GO:0009065)"
#  [33] "Platelet-Derived Growth Factor Receptor Signaling Pathway (GO:0048008)"
#  [34] "Negative Regulation Of Intrinsic Apoptotic Signaling Pathway By P53 Class Mediator (GO:1902254)"
#  [35] "Negative Regulation Of Amyloid-Beta Formation (GO:1902430)"
#  [36] "Endoplasmic Reticulum Tubular Network Organization (GO:0071786)"
#  [37] "Regulation Of B Cell Receptor Signaling Pathway (GO:0050855)"
# [125] "Negative Regulation Of Growth (GO:0045926)"
# [126] "Negative Regulation Of Cell Growth (GO:0030308)"
# [127] "Regulation Of Tumor Necrosis Factor Production (GO:0032680)"
# [128] "Protein Homooligomerization (GO:0051260)"
# [129] "Regulation Of Protein Kinase B Signaling (GO:0051896)"
# [130] "Actin Filament Organization (GO:0007015)"
# [131] "Regulation Of Cell Adhesion (GO:0030155)"
# [132] "Dephosphorylation (GO:0016311)"
# [133] "Skeletal System Development (GO:0001501)"
# [134] "Positive Regulation Of NF-kappaB Transcription Factor Activity (GO:0051092)"
# [135] "Cellular Response To Growth Factor Stimulus (GO:0071363)"
# [136] "Peptidyl-Serine Phosphorylation (GO:0018105)"
# [137] "Peptidyl-Serine Modification (GO:0018209)"
# [138] "Brain Development (GO:0007420)"
# [139] "Generation Of Neurons (GO:0048699)"
# [140] "Neuron Differentiation (GO:0030182)"
# [141] "Positive Regulation Of I-kappaB kinase/NF-kappaB Signaling (GO:0043123)"
# [142] "Positive Regulation Of ERK1 And ERK2 Cascade (GO:0070374)"
# [143] "Regulation Of MAPK Cascade (GO:0043408)"
# [144] "Regulation Of Angiogenesis (GO:0045765)"
# [145] "Regulation Of Cell Growth (GO:0001558)"
# [146] "Chromatin Remodeling (GO:0006338)"
# [147] "Negative Regulation Of Intracellular Signal Transduction (GO:1902532)"
# [148] "Regulation Of I-kappaB kinase/NF-kappaB Signaling (GO:0043122)"
# [149] "Inflammatory Response (GO:0006954)"
# [150] "Regulation Of ERK1 And ERK2 Cascade (GO:0070372)"
# [151] "Positive Regulation Of DNA-binding Transcription Factor Activity (GO:0051091)"
# [152] "Cytokine-Mediated Signaling Pathway (GO:0019221)"
# [153] "Cellular Component Assembly (GO:0022607)"
# [154] "Positive Regulation Of Signal Transduction (GO:0009967)"
# [155] "Chromatin Organization (GO:0006325)"
# [156] "Central Nervous System Development (GO:0007417)"
# [157] "Transmembrane Receptor Protein Tyrosine Kinase Signaling Pathway (GO:0007169)"
# [158] "Cellular Response To Cytokine Stimulus (GO:0071345)"
# [159] "Protein Transport (GO:0015031)"
# [160] "Supramolecular Fiber Organization (GO:0097435)"
# [161] "Negative Regulation Of Cell Population Proliferation (GO:0008285)"
# [162] "Negative Regulation Of Programmed Cell Death (GO:0043069)"
# [163] "Phosphorylation (GO:0016310)"
# [164] "Negative Regulation Of Apoptotic Process (GO:0043066)"
# [165] "Protein Phosphorylation (GO:0006468)"
# [166] "Negative Regulation Of Cellular Process (GO:0048523)"
# [167] "Positive Regulation Of Cellular Process (GO:0048522)"
# [168] "Regulation Of DNA-templated Transcription (GO:0006355)"
# [169] "Regulation Of Transcription By RNA Polymerase II (GO:0006357)"
# [170] "Regulation Of Apoptotic Process (GO:0042981)"
# [171] "Regulation Of Cell Population Proliferation (GO:0042127)"
# Connection changed to https://maayanlab.cloud/Enrichr/
#
# Connection is Live!
#   geneCoverage genesPerTerm libraryName
# 1 13362         275         Genome_Browser_PWMs
# 2 27884        1284         TRANSFAC_and_JASPAR_PWMs
# 3  6002          77         Transcription_Factor_PPIs
# 4 47172        1370         ChEA_2013
# 5 47107         509         Drug_Perturbations_from_GEO_2014
# 6 21493        3713         ENCODE_TF_ChIP-seq_2014
#   link                                                     numTerms
# 1 http://hgdownload.cse.ucsc.edu/goldenPath/hg18/database/ 615
# 2 http://jaspar.genereg.net/html/DOWNLOAD/                 326
# 3                                                          290
# 4 http://amp.pharm.mssm.edu/lib/cheadownload.jsp           353
# 5 http://www.ncbi.nlm.nih.gov/geo/                         701
# 6 http://genome.ucsc.edu/ENCODE/downloads.html             498
#   appyter                                  categoryId
# 1 ea115789fcbf12797fd692cec6df0ab4dbc79c6a 1
# 2 7d42eb43a64a4e3b20d721fc7148f685b53b6b30 1
# 3 849f222220618e2599d925b6b51868cf1dab3763 1
# 4 7ebe772afb55b63b41b79dd8d06ea0fdd9fa2630 7
# 5 ad270a6876534b7cb063e004289dcd4d3164f342 7
# 6 497787ebc418d308045efb63b8586f10c526af51 7
# Uploading data to Enrichr... Done.
#   Querying MSigDB_Hallmark_2020... Done.
#   Querying GO_Biological_Process_2023... Done.
# Parsing results... Done.
#   [1] "Negative Regulation Of Endocytosis (GO:0045806)"
#   [2] "Negative Regulation Of Gene Expression (GO:0010629)"
#   [3] "Extracellular Matrix Organization (GO:0030198)"
#   [4] "Cellular Response To Thyroid Hormone Stimulus (GO:0097067)"
#   [5] "Negative Regulation Of Macromolecule Metabolic Process (GO:0010605)"
#   [6] "Endocytosis (GO:0006897)"
#   [7] "Response To Thyroid Hormone (GO:0097066)"
#   [8] "Cell Morphogenesis Involved In Neuron Differentiation (GO:0048667)"
#   [9] "Negative Regulation Of Phagocytosis (GO:0050765)"
#  [10] "Response To Interleukin-1 (GO:0070555)"
#  [11] "Regulation Of JNK Cascade (GO:0046328)"
#  [12] "Positive Regulation Of T Cell Migration (GO:2000406)"
#  [13] "Negative Regulation Of Receptor-Mediated Endocytosis (GO:0048261)"
#  [14] "Antigen Processing And Presentation Of Exogenous Peptide Antigen Via MHC Class II (GO:0019886)"
#  [15] "Regulation Of Peptidase Activity (GO:0052547)"
#  [16] "Antigen Processing And Presentation Of Peptide Antigen Via MHC Class II (GO:0002495)"
#  [17] "Negative Regulation Of Plasma Membrane Bounded Cell Projection Assembly (GO:0120033)"
#  [18] "Antigen Processing And Presentation Of Exogenous Peptide Antigen (GO:0002478)"
#  [19] "Positive Regulation Of Cytokine Production (GO:0001819)"
#  [20] "Positive Regulation Of Small Molecule Metabolic Process (GO:0062013)"
#  [21] "Cellular Response To Amyloid-Beta (GO:1904646)"
#  [22] "Positive Regulation Of Carbohydrate Metabolic Process (GO:0045913)"
#  [23] "Regulation Of Macromolecule Metabolic Process (GO:0060255)"
#  [24] "Synaptic Vesicle Endocytosis (GO:0048488)"
#  [25] "Regulation Of Glycolytic Process (GO:0006110)"
#  [26] "Regulation Of Chemokine Production (GO:0032642)"
#  [27] "Regulation Of Cytokine Production (GO:0001817)"
#  [28] "Response To Amyloid-Beta (GO:1904645)"
# [495] "Inflammatory Response (GO:0006954)"
# [496] "Regulation Of Cell Population Proliferation (GO:0042127)"
# [497] "Positive Regulation Of DNA-binding Transcription Factor Activity (GO:0051091)"
# [498] "Positive Regulation Of Apoptotic Process (GO:0043065)"
# [499] "Plasma Membrane Bounded Cell Projection Assembly (GO:0120031)"
# [500] "Central Nervous System Development (GO:0007417)"
# [501] "Regulation Of Intracellular Signal Transduction (GO:1902531)"
# [502] "Positive Regulation Of MAPK Cascade (GO:0043410)"
# [503] "Supramolecular Fiber Organization (GO:0097435)"
# [504] "Protein-Containing Complex Assembly (GO:0065003)"
# [505] "Negative Regulation Of Cell Population Proliferation (GO:0008285)"
# [506] "Negative Regulation Of DNA-templated Transcription (GO:0045892)"
# [507] "Positive Regulation Of Multicellular Organismal Process (GO:0051240)"
# [508] "Organelle Organization (GO:0006996)"
# [509] "Regulation Of Cell Migration (GO:0030334)"
# [510] "Regulation Of Nucleic Acid-Templated Transcription (GO:1903506)"
# [511] "Positive Regulation Of Cell Population Proliferation (GO:0008284)"
# [512] "Regulation Of Transcription By RNA Polymerase II (GO:0006357)"
# [513] "Regulation Of Apoptotic Process (GO:0042981)"
# [514] "Negative Regulation Of Transcription By RNA Polymerase II (GO:0000122)"
# [515] "Regulation Of DNA-templated Transcription (GO:0006355)"

# %%
group_1_2_paths = c(
    "Positive Regulation Of Heterotypic Cell-Cell Adhesion (GO:0034116)",
    "Connective Tissue Development (GO:0061448)",
    "Positive Regulation Of Peptidyl-Serine Phosphorylation (GO:0033138)",
  "Inflammatory Response (GO:0006954)", 
  "Positive Regulation Of MAPK Cascade (GO:0043410)",
  "Positive Regulation Of Tumor Necrosis Factor Production (GO:0032760)",
  "Positive Regulation Of Intracellular Signal Transduction (GO:1902533)",
  "Positive Regulation Of ERK1 And ERK2 Cascade (GO:0070374)"    
)

group_3_4_paths = c(
  "Regulation Of Interleukin-10 Production (GO:0032653)",
  "Regulation Of Immune Effector Process (GO:0002697)",
  "Regulation Of T Cell Activation (GO:0050863)",
  "Regulation Of Adaptive Immune Response (GO:0002819)",
  "Negative Regulation Of Phagocytosis (GO:0050765)",
  "Negative Regulation Of Response To Stimulus (GO:0048585)",
  "Regulation Of Cytokine Production (GO:0001817)",
  "Negative Regulation Of Inflammatory Response (GO:0050728)"
)
all_pathways = c(group_1_2_paths,group_3_4_paths)
all_pathways

tmut_enr_total <- (mut_enr_total[mut_enr_total$Term %in% all_pathways,])
rownames(tmut_enr_total) <- tmut_enr_total$Term
tmut_enr_total <- tmut_enr_total[all_pathways,]
temp <- tmut_enr_total[,c('Adjusted.P.value','Odds.Ratio', 'Combined.Score', 'qscore')]
tmut_enr_total <- tmut_enr_total[,c()]
tmut_enr_total$p.val.pos <- temp$Adjusted.P.value
tmut_enr_total$q.score.pos <- temp$qscore
rownames(tmut_enr_total) <- all_pathways
tmut_enr_total$p.val.pos <- ifelse(is.na(tmut_enr_total$p.val.pos), 1, tmut_enr_total$p.val.pos)
tmut_enr_total$q.score.pos <- ifelse(is.na(tmut_enr_total$q.score.pos), 0, tmut_enr_total$q.score.pos)

tmut_enr_total_neg <- (mut_enr_total_neg[mut_enr_total_neg$Term %in% all_pathways,])
rownames(tmut_enr_total_neg) <- tmut_enr_total_neg$Term
tmut_enr_total_neg <- tmut_enr_total_neg[all_pathways,]
temp <- tmut_enr_total_neg[,c('Adjusted.P.value','Odds.Ratio', 'Combined.Score', 'qscore')]
tmut_enr_total_neg <- tmut_enr_total_neg[,c()]
tmut_enr_total_neg$p.val.neg <- temp$Adjusted.P.value
tmut_enr_total_neg$q.score.neg <- temp$qscore
rownames(tmut_enr_total_neg) <- all_pathways
# Fill p-values and q-scores with NA handling
tmut_enr_total_neg$p.val.neg <- ifelse(is.na(tmut_enr_total_neg$p.val.neg), 1, tmut_enr_total_neg$p.val.neg)
tmut_enr_total_neg$q.score.neg <- ifelse(is.na(tmut_enr_total_neg$q.score.neg), 0, tmut_enr_total_neg$q.score.neg)

tmut_enr_total_neg


tmut_enr_total_neg$q.score.neg <- rescale(tmut_enr_total_neg$q.score.neg, to=c(0,1))
tmut_enr_total$p.val.neg <- rescale(tmut_enr_total$p.val.neg, to=c(0,1))
# Out:
#  [1] "Positive Regulation Of Heterotypic Cell-Cell Adhesion (GO:0034116)"
#  [2] "Connective Tissue Development (GO:0061448)"
#  [3] "Positive Regulation Of Peptidyl-Serine Phosphorylation (GO:0033138)"
#  [4] "Inflammatory Response (GO:0006954)"
#  [5] "Positive Regulation Of MAPK Cascade (GO:0043410)"
#  [6] "Positive Regulation Of Tumor Necrosis Factor Production (GO:0032760)"
#  [7] "Positive Regulation Of Intracellular Signal Transduction (GO:1902533)"
#  [8] "Positive Regulation Of ERK1 And ERK2 Cascade (GO:0070374)"
#  [9] "Regulation Of Interleukin-10 Production (GO:0032653)"
# [10] "Regulation Of Immune Effector Process (GO:0002697)"
# [11] "Regulation Of T Cell Activation (GO:0050863)"
# [12] "Regulation Of Adaptive Immune Response (GO:0002819)"
# [13] "Negative Regulation Of Phagocytosis (GO:0050765)"
# [14] "Negative Regulation Of Response To Stimulus (GO:0048585)"
# [15] "Regulation Of Cytokine Production (GO:0001817)"
# [16] "Negative Regulation Of Inflammatory Response (GO:0050728)"
#                                                                       p.val.neg
# Positive Regulation Of Heterotypic Cell-Cell Adhesion (GO:0034116)    1.00000000
# Connective Tissue Development (GO:0061448)                            1.00000000
# Positive Regulation Of Peptidyl-Serine Phosphorylation (GO:0033138)   0.14224475
# Inflammatory Response (GO:0006954)                                    0.28544712
# Positive Regulation Of MAPK Cascade (GO:0043410)                      0.35321687
# Positive Regulation Of Tumor Necrosis Factor Production (GO:0032760)  0.13063056
# Positive Regulation Of Intracellular Signal Transduction (GO:1902533) 0.17932310
# Positive Regulation Of ERK1 And ERK2 Cascade (GO:0070374)             0.23282629
# Regulation Of Interleukin-10 Production (GO:0032653)                  0.09616964
# Regulation Of Immune Effector Process (GO:0002697)                    0.06147505
# Regulation Of T Cell Activation (GO:0050863)                          0.11510588
# Regulation Of Adaptive Immune Response (GO:0002819)                   0.06347200
# Negative Regulation Of Phagocytosis (GO:0050765)                      0.01036635
# Negative Regulation Of Response To Stimulus (GO:0048585)              0.10318270
# Regulation Of Cytokine Production (GO:0001817)                        0.02753049
# Negative Regulation Of Inflammatory Response (GO:0050728)             0.16414874
#                                                                       q.score.neg
# Positive Regulation Of Heterotypic Cell-Cell Adhesion (GO:0034116)    0.0000000
# Connective Tissue Development (GO:0061448)                            0.0000000
# Positive Regulation Of Peptidyl-Serine Phosphorylation (GO:0033138)   0.8469637
# Inflammatory Response (GO:0006954)                                    0.5444743
# Positive Regulation Of MAPK Cascade (GO:0043410)                      0.4519586
# Positive Regulation Of Tumor Necrosis Factor Production (GO:0032760)  0.8839552
# Positive Regulation Of Intracellular Signal Transduction (GO:1902533) 0.7463638
# Positive Regulation Of ERK1 And ERK2 Cascade (GO:0070374)             0.6329680
# Regulation Of Interleukin-10 Production (GO:0032653)                  1.0169620
# Regulation Of Immune Effector Process (GO:0002697)                    1.2113011
# Regulation Of T Cell Activation (GO:0050863)                          0.9389025
# Regulation Of Adaptive Immune Response (GO:0002819)                   1.1974178
# Negative Regulation Of Phagocytosis (GO:0050765)                      1.9843743
# Negative Regulation Of Response To Stimulus (GO:0048585)              0.9863931
# Regulation Of Cytokine Production (GO:0001817)                        1.5601860
# Negative Regulation Of Inflammatory Response (GO:0050728)             0.7847625

# %%
tmut_enr_total$Term <- rownames(tmut_enr_total)
tmut_enr_total$Term <- factor(tmut_enr_total$Term, levels = tmut_enr_total$Term)

ggplot(tmut_enr_total, aes(x = Term , y =  q.score.pos, 
                                  fill=p.val.pos)) +
  geom_col( width = 0.7) +
    scale_fill_gradient( limits = c(0, 0.5)) +
 coord_flip() +  theme(panel.background = element_blank(),
        panel.grid.major = element_blank(),
        panel.grid.minor = element_blank(),
        axis.line = element_line(color = "black"))
# Out:
# plot without title

# %%
tmut_enr_total_neg$Term <- rownames(tmut_enr_total_neg)

tmut_enr_total_neg$Term <- gsub(" \\(GO:.*$", "", rownames(tmut_enr_total_neg))
tmut_enr_total_neg$Term <- gsub("positive regulation of ", "+ ", tmut_enr_total_neg$Term, ignore.case = TRUE)
tmut_enr_total_neg$Term <- gsub("negative regulation of ", "- ", tmut_enr_total_neg$Term, ignore.case = TRUE)

tmut_enr_total_neg$Term <- factor(tmut_enr_total_neg$Term, levels = tmut_enr_total_neg$Term)


tmut_enr_total_neg$Term <- factor(tmut_enr_total_neg$Term, levels = tmut_enr_total_neg$Term)

ggplot(tmut_enr_total_neg, aes(x = Term , y =  q.score.neg, 
                                  fill=p.val.neg)) +
  geom_col( width = 0.7) +
      scale_fill_gradient( limits = c(0, 0.5)) + coord_flip() +
  theme(panel.background = element_blank(),
        panel.grid.major = element_blank(),
        panel.grid.minor = element_blank(),
        axis.line = element_line(color = "black"),
           axis.text.y = element_text(size = 12, color = "black") # Increase font size for y-axis tick labels
)
# Out:
# plot without title
